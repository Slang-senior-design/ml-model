# %% [markdown]
# The data is loaded from the CSV file and the target variable converted to one-hot encodings.

# %%
import pandas as pd
columns = ["pixel"+str(i) for i in range(10000)]
df = pd.read_csv("mapping.csv", names=["class"]+columns, dtype={'class':str, 'img':str})
df.head()
# Out:
#    class  pixel0  pixel1  pixel2  pixel3  pixel4  pixel5  pixel6  pixel7  \
# 0  alone     109     109     109     109     109     109     109     109
# 1  alone     109     109     109     109     109     109     109     109
# 2  alone     109     109     109     109     109     109     109     109
# 3  alone     109     109     109     109     109     109     109     109
# 4  alone     109     109     109     109     109     109     109     109
#
#    pixel8  ...  pixel9990  pixel9991  pixel9992  pixel9993  pixel9994  \
# 0     109  ...        109        109        109        109        109
# 1     109  ...        109        109        109        109        109
# 2     109  ...        109        109        109        109        109
# 3     109  ...        109        109        109        109        109
# 4     109  ...        109        109        109        109        109
#
#    pixel9995  pixel9996  pixel9997  pixel9998  pixel9999
# 0        109        109        109        109        109
# 1        109        109        109        109        109
# 2        109        109        109        109        109
# 3        109        109        109        109        109
# 4        109        109        109        109        109
#
# [5 rows x 10001 columns]

# %%
df.shape
# Out:
# (169, 10001)

# %%
from sklearn import preprocessing
import numpy as np
from keras.utils import np_utils

n = df.shape[0]
nb_classes = df["class"].nunique()

le = preprocessing.LabelEncoder()
classes = df["class"]
le.fit(classes)
df["class"] = le.transform(classes)

X = df.iloc[:, 1:] # everything but the class

y = df["class"]
y = np_utils.to_categorical(y, nb_classes) #one hot encodings
# Out:
# Using TensorFlow backend.

# %% [markdown]
# The pixel data is reshaped because the ImageDataGenerator takes a 3D representation of a image - (width, height, channel). Grayscale images have one channel but color images contain RGB data. Then the data is split into training and testing sets.

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_recall_fscore_support

n = X.shape[0]
X = np.array(X).reshape(n, 100, 100, 1)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((135, 100, 100, 1), (34, 100, 100, 1), (135, 3), (34, 3))

# %% [markdown]
# We create an `ImageDataGenerator` object that will supplement our training data and help the model generalize better. The train and test data generators will also normalize the data.

# %%
from keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(
#         rotation_range=40,
        width_shift_range=0.2,
        height_shift_range=0.2,
#         rescale=1./255,
#         shear_range=0.2,
#         zoom_range=0.2,
        horizontal_flip=True,
        fill_mode='nearest')

test_datagen = ImageDataGenerator(rescale=1./255)

# %%
train_generator = train_datagen.flow(X_train, y_train)
test_generator = test_datagen.flow(X_test, y_test)

# %% [markdown]
# A sample of the images generated by the train generator and the some of the original images are displayed below.

# %%
import matplotlib.pyplot as plt

p = train_generator.next()
rows = 2
cols = 4

fig=plt.figure(figsize=(cols*4, rows*4))
for i in range(1, 9):
    img = np.squeeze(p[0][i-1])
    fig.add_subplot(rows, cols, i)
    plt.imshow(img, cmap="gray")
plt.show()

# %%
fig=plt.figure(figsize=(16, 8))
cols = 4
rows = 2

for i in range(1, cols*rows+1):
    img = np.squeeze(X[i-1])
    fig.add_subplot(rows, cols, i)
    plt.imshow(img, cmap="gray")
plt.show()

# %% [markdown]
# We then define a function to build a convolutional neural network with 3 convolutions using 3x3 kernels, ReLU activation and max-pooling. Finally, logistic regression is used to predict the output of the model. A dropout layer is added to further generalize the model and prevent it from overfitting.

# %%
from keras.models import Sequential 
from keras.layers import Dense, Activation, Flatten, Dropout, Conv2D, MaxPooling2D
from keras import optimizers

input_shape=(100, 100, 1)

def create_model(lr=0.1):
    model = Sequential()
#     model.add(Conv2D(32, (3, 3), input_shape=input_shape))
#     model.add(Activation('relu'))
#     model.add(MaxPooling2D(pool_size=(2, 2)))

#     model.add(Conv2D(32, (3, 3)))
#     model.add(Activation('relu'))
#     model.add(MaxPooling2D(pool_size=(2, 2)))

#     model.add(Conv2D(32, (3, 3)))
#     model.add(Activation('relu'))
#     model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Flatten())
#     model.add(Dense(64, input_shape=input_shape))
#     model.add(Dropout(0.5))
    model.add(Dense(nb_classes, activation='softmax'))
    opt = optimizers.Adam(lr=lr)
    model.compile(loss="categorical_crossentropy", optimizer='adam', metrics=["accuracy"])
    return model

# %% [markdown]
# We arbitrarily choose the initial batch size and epochs to establish a baseline.

# %%
batch_size=32
epochs=20

# %% [markdown]
# Fit the unaugumented train data first to make sure everything is running correctly, then train the model using generated data.

# %%
model = create_model()
# output_dim = nb_classes
# input_dim = input_shape
# model = Sequential() 
# model.add(Flatten())
# model.add(Dense(output_dim, activation='softmax')) 
# model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy']) 
history = model.fit(X_train/255, y_train, batch_size=batch_size, epochs=epochs)
# Out:
# Epoch 1/20
# 135/135 [==============================] - 0s 3ms/step - loss: 6.3206 - acc: 0.3481
# Epoch 2/20
# 135/135 [==============================] - 0s 222us/step - loss: 8.5963 - acc: 0.4667
# Epoch 3/20
# 135/135 [==============================] - 0s 259us/step - loss: 8.5963 - acc: 0.4667
# Epoch 4/20
# 135/135 [==============================] - 0s 236us/step - loss: 8.5963 - acc: 0.4667
# Epoch 5/20
# 135/135 [==============================] - 0s 244us/step - loss: 8.5963 - acc: 0.4667
# Epoch 6/20
# 135/135 [==============================] - 0s 251us/step - loss: 8.5963 - acc: 0.4667
# Epoch 7/20
# 135/135 [==============================] - 0s 258us/step - loss: 8.5963 - acc: 0.4667
# Epoch 8/20
# 135/135 [==============================] - 0s 266us/step - loss: 8.5963 - acc: 0.4667
# Epoch 9/20
# 135/135 [==============================] - 0s 288us/step - loss: 8.5963 - acc: 0.4667
# Epoch 10/20
# 135/135 [==============================] - 0s 281us/step - loss: 8.5963 - acc: 0.4667
# Epoch 11/20
# 135/135 [==============================] - 0s 266us/step - loss: 8.5963 - acc: 0.4667
# Epoch 12/20
# 135/135 [==============================] - 0s 222us/step - loss: 8.5963 - acc: 0.4667
# Epoch 13/20
# 135/135 [==============================] - 0s 273us/step - loss: 8.5963 - acc: 0.4667
# Epoch 14/20
# 135/135 [==============================] - 0s 259us/step - loss: 8.5963 - acc: 0.4667
# Epoch 15/20
# 135/135 [==============================] - 0s 251us/step - loss: 8.5963 - acc: 0.4667
# Epoch 16/20
# 135/135 [==============================] - 0s 259us/step - loss: 8.5963 - acc: 0.4667
# Epoch 17/20
# 135/135 [==============================] - 0s 281us/step - loss: 8.5963 - acc: 0.4667
# Epoch 18/20
# 135/135 [==============================] - 0s 273us/step - loss: 8.5963 - acc: 0.4667
# Epoch 19/20
# 135/135 [==============================] - 0s 280us/step - loss: 8.5963 - acc: 0.4667
# Epoch 20/20
# 135/135 [==============================] - 0s 266us/step - loss: 8.5963 - acc: 0.4667

# %%
import matplotlib.pyplot as plt

plt.ylim(0, 1)
plt.plot(history.history["acc"], label="accuracy")
plt.legend(loc="upper left")
plt.xlabel("epoch")
plt.ylabel("accuracy")
plt.xticks(np.arange(0, 20+1, 10));

# %%
model = create_model()
history = model.fit_generator(train_generator,
        steps_per_epoch=5, #2000 // batch_size,
        epochs=epochs,
        validation_data=test_generator,
        validation_steps=2) #800 // batch_size)
model.save_weights('cnn3.h5')
# Out:
# Epoch 1/20
# 5/5 [==============================] - 2s 492ms/step - loss: 6.4121 - acc: 0.5447 - val_loss: 11.3775 - val_acc: 0.2941
# Epoch 2/20
# 5/5 [==============================] - 1s 240ms/step - loss: 7.7416 - acc: 0.5197 - val_loss: 9.9553 - val_acc: 0.3824
# Epoch 3/20
# 5/5 [==============================] - 1s 280ms/step - loss: 7.3380 - acc: 0.5447 - val_loss: 9.9553 - val_acc: 0.3824
# Epoch 4/20
# 5/5 [==============================] - 1s 236ms/step - loss: 7.3497 - acc: 0.5440 - val_loss: 10.4294 - val_acc: 0.3529
# Epoch 5/20
# 5/5 [==============================] - 1s 236ms/step - loss: 7.2341 - acc: 0.5512 - val_loss: 10.9034 - val_acc: 0.3235
# Epoch 6/20
# 5/5 [==============================] - 1s 233ms/step - loss: 8.0415 - acc: 0.5011 - val_loss: 10.4294 - val_acc: 0.3529
# Epoch 7/20
# 5/5 [==============================] - 1s 280ms/step - loss: 7.7299 - acc: 0.5204 - val_loss: 10.4294 - val_acc: 0.3529
# Epoch 8/20
# 5/5 [==============================] - 1s 234ms/step - loss: 8.3530 - acc: 0.4818 - val_loss: 10.4294 - val_acc: 0.3529
# Epoch 9/20
# 5/5 [==============================] - 1s 233ms/step - loss: 7.5457 - acc: 0.5319 - val_loss: 10.4294 - val_acc: 0.3529
# Epoch 10/20
# 5/5 [==============================] - 1s 235ms/step - loss: 7.5574 - acc: 0.5311 - val_loss: 9.9553 - val_acc: 0.3824
# Epoch 11/20
# 5/5 [==============================] - 1s 275ms/step - loss: 7.8338 - acc: 0.5140 - val_loss: 10.9034 - val_acc: 0.3235
# Epoch 12/20
# 5/5 [==============================] - 1s 237ms/step - loss: 6.8422 - acc: 0.5755 - val_loss: 10.9034 - val_acc: 0.3235
# Epoch 13/20
# 5/5 [==============================] - 1s 232ms/step - loss: 8.0415 - acc: 0.5011 - val_loss: 9.9553 - val_acc: 0.3824
# Epoch 14/20
# 5/5 [==============================] - 1s 239ms/step - loss: 7.3380 - acc: 0.5447 - val_loss: 9.9553 - val_acc: 0.3824
# Epoch 15/20
# 5/5 [==============================] - 1s 277ms/step - loss: 7.5339 - acc: 0.5326 - val_loss: 10.4294 - val_acc: 0.3529
# Epoch 16/20
# 5/5 [==============================] - 1s 236ms/step - loss: 7.5574 - acc: 0.5311 - val_loss: 10.4294 - val_acc: 0.3529
# Epoch 17/20
# 5/5 [==============================] - 1s 232ms/step - loss: 6.7501 - acc: 0.5812 - val_loss: 10.9034 - val_acc: 0.3235
# Epoch 18/20
# 5/5 [==============================] - 1s 246ms/step - loss: 8.5607 - acc: 0.4689 - val_loss: 10.4294 - val_acc: 0.3529
# Epoch 19/20
# 5/5 [==============================] - 1s 281ms/step - loss: 5.9193 - acc: 0.6328 - val_loss: 10.9034 - val_acc: 0.3235
# Epoch 20/20
# 5/5 [==============================] - 1s 246ms/step - loss: 7.1303 - acc: 0.5576 - val_loss: 9.9553 - val_acc: 0.3824

# %% [markdown]
# Print test and validation accuracies:

# %%
import matplotlib.pyplot as plt

plt.ylim(0, 1)
plt.plot(history.history["acc"], label="accuracy")
plt.plot(history.history["val_acc"], label="val_accuracy")
plt.legend(loc="upper left")
plt.xlabel("epoch")
plt.ylabel("accuracy")
plt.xticks(np.arange(0, 20+1, 10));

# %% [markdown]
# # Tuning

# %%
from keras import optimizers
from sklearn.model_selection import GridSearchCV
from keras.wrappers.scikit_learn import KerasClassifier

learn_rate = [0.001, 0.01, 0.1, 0.2, 0.3]
epochs = [i*10 for i in range(6)]
batch_size = [10, 20, 40, 60, 80]
X_train, X_test, y_train, y_test = train_test_split(X, classes, test_size=0.20)

grid_values = {'epochs': epochs, "lr": learn_rate}
model = KerasClassifier(build_fn=create_model)
grid_acc = GridSearchCV(model, param_grid = grid_values,scoring = 'accuracy', cv=3)
grid_result = grid_acc.fit(X_train, y_train)

# %%
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))

# %% [markdown]
# # Retrain

# %% [markdown]
# Retrain model using paramters lr=0.001 and epochs=30 found using GridSearchCV.

# %%
model = create_model(lr=0.001)
history = model.fit_generator(train_generator,
        steps_per_epoch=5, #2000 // batch_size,
        epochs=30,
        validation_data=test_generator,
        validation_steps=2) #800 // batch_size)
model.save_weights('first_try.h5')
# Out:
# Epoch 1/30
# 5/5 [==============================] - 3s 573ms/step - loss: 1.0284 - acc: 0.5576 - val_loss: 1.2147 - val_acc: 0.3529
# Epoch 2/30
# 5/5 [==============================] - 1s 290ms/step - loss: 1.0719 - acc: 0.4681 - val_loss: 1.0871 - val_acc: 0.3529
# Epoch 3/30
# 5/5 [==============================] - 1s 261ms/step - loss: 1.0384 - acc: 0.5254 - val_loss: 1.2847 - val_acc: 0.3529
# Epoch 4/30
# 5/5 [==============================] - 1s 234ms/step - loss: 1.0449 - acc: 0.5311 - val_loss: 1.1944 - val_acc: 0.3529
# Epoch 5/30
# 5/5 [==============================] - 1s 253ms/step - loss: 0.9887 - acc: 0.5963 - val_loss: 1.1285 - val_acc: 0.3529
# Epoch 6/30
# 5/5 [==============================] - 1s 277ms/step - loss: 1.0470 - acc: 0.4868 - val_loss: 1.1317 - val_acc: 0.3529
# Epoch 7/30
# 5/5 [==============================] - 1s 237ms/step - loss: 0.9398 - acc: 0.5963 - val_loss: 1.3558 - val_acc: 0.3529
# Epoch 8/30
# 5/5 [==============================] - 1s 242ms/step - loss: 1.0475 - acc: 0.4932 - val_loss: 1.0989 - val_acc: 0.3529
# Epoch 9/30
# 5/5 [==============================] - 1s 256ms/step - loss: 1.0022 - acc: 0.5641 - val_loss: 1.1636 - val_acc: 0.3529
# Epoch 10/30
# 5/5 [==============================] - 1s 294ms/step - loss: 1.0193 - acc: 0.5061 - val_loss: 1.1957 - val_acc: 0.3529
# Epoch 11/30
# 5/5 [==============================] - 1s 240ms/step - loss: 0.9853 - acc: 0.5698 - val_loss: 1.1580 - val_acc: 0.3529
# Epoch 12/30
# 5/5 [==============================] - 1s 286ms/step - loss: 0.9931 - acc: 0.5505 - val_loss: 1.1644 - val_acc: 0.3529
# Epoch 13/30
# 5/5 [==============================] - 1s 276ms/step - loss: 0.9321 - acc: 0.5698 - val_loss: 1.1848 - val_acc: 0.3529
# Epoch 14/30
# 5/5 [==============================] - 1s 282ms/step - loss: 0.9446 - acc: 0.5319 - val_loss: 1.1445 - val_acc: 0.3529
# Epoch 15/30
# 5/5 [==============================] - 1s 249ms/step - loss: 0.9359 - acc: 0.5261 - val_loss: 1.1283 - val_acc: 0.3529
# Epoch 16/30
# 5/5 [==============================] - 1s 278ms/step - loss: 0.8572 - acc: 0.5891 - val_loss: 1.2144 - val_acc: 0.3529
# Epoch 17/30
# 5/5 [==============================] - 1s 295ms/step - loss: 0.8971 - acc: 0.5383 - val_loss: 1.0609 - val_acc: 0.3529
# Epoch 18/30
# 5/5 [==============================] - 1s 264ms/step - loss: 0.8664 - acc: 0.5583 - val_loss: 1.2062 - val_acc: 0.3529
# Epoch 19/30
# 5/5 [==============================] - 1s 237ms/step - loss: 0.9223 - acc: 0.4932 - val_loss: 1.2226 - val_acc: 0.2647
# Epoch 20/30
# 5/5 [==============================] - 1s 226ms/step - loss: 0.8992 - acc: 0.5068 - val_loss: 1.0521 - val_acc: 0.3529
# Epoch 21/30
# 5/5 [==============================] - 1s 288ms/step - loss: 0.8619 - acc: 0.5633 - val_loss: 1.1809 - val_acc: 0.3529
# Epoch 22/30
# 5/5 [==============================] - 1s 280ms/step - loss: 0.9280 - acc: 0.5254 - val_loss: 1.1600 - val_acc: 0.3235
# Epoch 23/30
# 5/5 [==============================] - 1s 252ms/step - loss: 0.8055 - acc: 0.5512 - val_loss: 1.0746 - val_acc: 0.2647
# Epoch 24/30
# 5/5 [==============================] - 1s 269ms/step - loss: 0.8654 - acc: 0.5319 - val_loss: 1.1291 - val_acc: 0.2647
# Epoch 25/30
# 5/5 [==============================] - 1s 277ms/step - loss: 0.8450 - acc: 0.5061 - val_loss: 1.0854 - val_acc: 0.2941
# Epoch 26/30
# 5/5 [==============================] - 1s 235ms/step - loss: 0.8151 - acc: 0.5633 - val_loss: 1.1459 - val_acc: 0.2647
# Epoch 27/30
# 5/5 [==============================] - 1s 245ms/step - loss: 0.8194 - acc: 0.5383 - val_loss: 1.1741 - val_acc: 0.4118
# Epoch 28/30
# 5/5 [==============================] - 1s 259ms/step - loss: 0.7785 - acc: 0.5827 - val_loss: 1.2258 - val_acc: 0.4118
# Epoch 29/30
# 5/5 [==============================] - 2s 317ms/step - loss: 0.8199 - acc: 0.5705 - val_loss: 1.0285 - val_acc: 0.5588
# Epoch 30/30
# 5/5 [==============================] - 1s 247ms/step - loss: 0.8365 - acc: 0.5576 - val_loss: 1.1977 - val_acc: 0.4118

# %%
import matplotlib.pyplot as plt

plt.ylim(0, 1)
plt.plot(history.history["acc"], label="accuracy")
plt.plot(history.history["val_acc"], label="val_accuracy")
plt.legend(loc="upper left")
plt.xlabel("epoch")
plt.ylabel("accuracy")
plt.xticks(np.arange(0, 30+1, 10));
